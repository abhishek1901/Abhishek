# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
data = pd.read_csv("http://bit.ly/w-data")
data
# Out:
#     Hours  Scores
# 0     2.5      21
# 1     5.1      47
# 2     3.2      27
# 3     8.5      75
# 4     3.5      30
# 5     1.5      20
# 6     9.2      88
# 7     5.5      60
# 8     8.3      81
# 9     2.7      25
# 10    7.7      85
# 11    5.9      62
# 12    4.5      41
# 13    3.3      42
# 14    1.1      17
# 15    8.9      95
# 16    2.5      30
# 17    1.9      24
# 18    6.1      67
# 19    7.4      69
# 20    2.7      30
# 21    4.8      54
# 22    3.8      35
# 23    6.9      76
# 24    7.8      86

# %%
data.plot(x='Hours',y='Scores',style='ro')
plt.title('DATA PLOT FOR HOURS VS SCORES')
plt.xlabel('HOURS')
plt.ylabel('SCORES')
plt.show()

# %%
X = data.iloc[:,:-1]
y = data.iloc[:,1]
from sklearn.model_selection import train_test_split

X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.3,random_state=0)

# %%
from sklearn.linear_model import LinearRegression
model = LinearRegression().fit(X_train,y_train)
line = model.coef_ *X+model.intercept_
plt.scatter(X, y)
plt.plot(X,line)
plt.show()

# %%
y_pred = model.predict(X_test)
df = pd.DataFrame({'Actual': y_test, 'Predicted': y_pred})  
df
# Out:
#     Actual  Predicted
# 5       20  17.053665
# 2       27  33.694229
# 19      69  74.806209
# 16      30  26.842232
# 11      62  60.123359
# 22      35  39.567369
# 17      24  20.969092
# 24      86  78.721636

# %%
hours = 9.25
hours_array = np.array(hours).reshape(-1,1)
own_pred = model.predict(hours_array)
print("No of Hours = {}".format(hours_array))
print("Predicted Score = {}".format(own_pred[0]))
# Out:
# No of Hours = [[9.25]]
# Predicted Score = 92.91505723477056

# %%
from sklearn import metrics  
print('Mean Absolute Error:', 
      metrics.mean_absolute_error(y_test, y_pred))
# Out:
# Mean Absolute Error: 4.419727808027651
